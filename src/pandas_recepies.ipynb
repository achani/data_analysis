# %% [markdown]
# ## 1. Explode

# %%
import pandas as pd
from pathlib import Path

org_data_path = Path.cwd().parent / "data" / "heirarchy.csv" 

pd.set_option("display.max_columns", 85)
pd.set_option("display.max_rows", None)

# %%
df = pd.DataFrame({'A': [[1, 2, 3], [], [3, 4]], 'B': 1})
df
# Out:
#            A  B
# 0  [1, 2, 3]  1
# 1         []  1
# 2     [3, 4]  1

# %%
df = df.explode('A')

# %%
df.reset_index()
# Out:
#    index    A  B
# 0      0    1  1
# 1      0    2  1
# 2      0    3  1
# 3      1  NaN  1
# 4      2    3  1
# 5      2    4  1

# %%
df
# Out:
#      A  B
# 0    1  1
# 0    2  1
# 0    3  1
# 1  NaN  1
# 2    3  1
# 2    4  1

# %% [markdown]
# ## 2. Create a heirarchy of levels

# %%
org = pd.read_csv(org_data_path)

# %%
org
# Out:
#       dept   parent
# 0        x  ABCD123
# 1  ABCD123   ABCD12
# 2   ABCD12    ABCD1
# 3    ABCD1     ABCD
# 4     ABCD      ABC
# 5      ABC       AB
# 6       AB        A
# 7        A        Z

# %%
org_temp = org.copy()

# %%
#org_temp.rename(columns={'dept':'1', 'parent':'2'},inplace=True)

# %%
org_temp
# Out:
#       dept   parent
# 0        x  ABCD123
# 1  ABCD123   ABCD12
# 2   ABCD12    ABCD1
# 3    ABCD1     ABCD
# 4     ABCD      ABC
# 5      ABC       AB
# 6       AB        A
# 7        A        Z

# %%
org_new = org.copy()
org_new = org_new.rename(columns={'dept': '1', 'parent':'2'})
org_new
# Out:
#          1        2
# 0        x  ABCD123
# 1  ABCD123   ABCD12
# 2   ABCD12    ABCD1
# 3    ABCD1     ABCD
# 4     ABCD      ABC
# 5      ABC       AB
# 6       AB        A
# 7        A        Z

# %%
for col in range(2,20):
    org_initial = org_temp.rename(columns={'dept':str(col)})
    org_new = org_new.merge(org_initial,how="left")
    org_new = org_new.rename(columns={'parent': str(col+1)})

    org_null_values = org_new[org_new[str(col)].notnull()]
    if org_null_values.shape[0] == 0: 
        org_new = org_new.drop(str(col), axis='columns')
        org_new = org_new.drop(str(col+1), axis='columns')
        break
org_new
# Out:
#          1        2       3      4     5    6    7    8    9
# 0        x  ABCD123  ABCD12  ABCD1  ABCD  ABC   AB    A    Z
# 1  ABCD123   ABCD12   ABCD1   ABCD   ABC   AB    A    Z  NaN
# 2   ABCD12    ABCD1    ABCD    ABC    AB    A    Z  NaN  NaN
# 3    ABCD1     ABCD     ABC     AB     A    Z  NaN  NaN  NaN
# 4     ABCD      ABC      AB      A     Z  NaN  NaN  NaN  NaN
# 5      ABC       AB       A      Z   NaN  NaN  NaN  NaN  NaN
# 6       AB        A       Z    NaN   NaN  NaN  NaN  NaN  NaN
# 7        A        Z     NaN    NaN   NaN  NaN  NaN  NaN  NaN

# %%
org_new.columns
# Out:
# Index(['1', '2', '3', '4', '5', '6', '7', '8', '9'], dtype='object')

# %%
cols = org_new.columns
def create_map(row):
    return [{col:row[col]} for _,col in enumerate(cols)]

#orders['obj'] = orders.apply(create_map, axis=1)

org_new['kvs']= org_new.apply(create_map, axis=1)
org_new
# Out:
#          1        2       3      4     5    6    7    8    9  \
# 0        x  ABCD123  ABCD12  ABCD1  ABCD  ABC   AB    A    Z
# 1  ABCD123   ABCD12   ABCD1   ABCD   ABC   AB    A    Z  NaN
# 2   ABCD12    ABCD1    ABCD    ABC    AB    A    Z  NaN  NaN
# 3    ABCD1     ABCD     ABC     AB     A    Z  NaN  NaN  NaN
# 4     ABCD      ABC      AB      A     Z  NaN  NaN  NaN  NaN
# 5      ABC       AB       A      Z   NaN  NaN  NaN  NaN  NaN
# 6       AB        A       Z    NaN   NaN  NaN  NaN  NaN  NaN
# 7        A        Z     NaN    NaN   NaN  NaN  NaN  NaN  NaN
#
#                                                  kvs
# 0  [{'1': 'x'}, {'2': 'ABCD123'}, {'3': 'ABCD12'}...
# 1  [{'1': 'ABCD123'}, {'2': 'ABCD12'}, {'3': 'ABC...
# 2  [{'1': 'ABCD12'}, {'2': 'ABCD1'}, {'3': 'ABCD'...
# 3  [{'1': 'ABCD1'}, {'2': 'ABCD'}, {'3': 'ABC'}, ...
# 4  [{'1': 'ABCD'}, {'2': 'ABC'}, {'3': 'AB'}, {'4...
# 5  [{'1': 'ABC'}, {'2': 'AB'}, {'3': 'A'}, {'4': ...
# 6  [{'1': 'AB'}, {'2': 'A'}, {'3': 'Z'}, {'4': na...
# 7  [{'1': 'A'}, {'2': 'Z'}, {'3': nan}, {'4': nan...

# %%
org_new = org_new.loc[ : , ['1','kvs']]
org_bk = org_new.copy()
org_new
# Out:
#          1                                                kvs
# 0        x  [{'1': 'x'}, {'2': 'ABCD123'}, {'3': 'ABCD12'}...
# 1  ABCD123  [{'1': 'ABCD123'}, {'2': 'ABCD12'}, {'3': 'ABC...
# 2   ABCD12  [{'1': 'ABCD12'}, {'2': 'ABCD1'}, {'3': 'ABCD'...
# 3    ABCD1  [{'1': 'ABCD1'}, {'2': 'ABCD'}, {'3': 'ABC'}, ...
# 4     ABCD  [{'1': 'ABCD'}, {'2': 'ABC'}, {'3': 'AB'}, {'4...
# 5      ABC  [{'1': 'ABC'}, {'2': 'AB'}, {'3': 'A'}, {'4': ...
# 6       AB  [{'1': 'AB'}, {'2': 'A'}, {'3': 'Z'}, {'4': na...
# 7        A  [{'1': 'A'}, {'2': 'Z'}, {'3': nan}, {'4': nan...

# %%
org_new = org_new.explode('kvs')

# %%
org_new.shape
# Out:
# (72, 2)

# %% [markdown]
# https://stackoverflow.com/questions/23586510/return-multiple-columns-from-pandas-apply

# %%
import ast

def extract(s):
    depth = next(iter(s['kvs']))
    s['depth'] = depth
    s['parent'] = s['kvs'][depth]
    return s
org_new = org_new.apply(extract,axis=1)
org_new
# Out:
#          1               kvs depth   parent
# 0        x        {'1': 'x'}     1        x
# 0        x  {'2': 'ABCD123'}     2  ABCD123
# 0        x   {'3': 'ABCD12'}     3   ABCD12
# 0        x    {'4': 'ABCD1'}     4    ABCD1
# 0        x     {'5': 'ABCD'}     5     ABCD
# 0        x      {'6': 'ABC'}     6      ABC
# 0        x       {'7': 'AB'}     7       AB
# 0        x        {'8': 'A'}     8        A
# 0        x        {'9': 'Z'}     9        Z
# 1  ABCD123  {'1': 'ABCD123'}     1  ABCD123
# 1  ABCD123   {'2': 'ABCD12'}     2   ABCD12
# 1  ABCD123    {'3': 'ABCD1'}     3    ABCD1
# 1  ABCD123     {'4': 'ABCD'}     4     ABCD
# 1  ABCD123      {'5': 'ABC'}     5      ABC
# 1  ABCD123       {'6': 'AB'}     6       AB
# 1  ABCD123        {'7': 'A'}     7        A
# 1  ABCD123        {'8': 'Z'}     8        Z
# 1  ABCD123        {'9': nan}     9      NaN
# 2   ABCD12   {'1': 'ABCD12'}     1   ABCD12
# 2   ABCD12    {'2': 'ABCD1'}     2    ABCD1
# 2   ABCD12     {'3': 'ABCD'}     3     ABCD
# 2   ABCD12      {'4': 'ABC'}     4      ABC
# 2   ABCD12       {'5': 'AB'}     5       AB
# 2   ABCD12        {'6': 'A'}     6        A
# 2   ABCD12        {'7': 'Z'}     7        Z
# 2   ABCD12        {'8': nan}     8      NaN
# 2   ABCD12        {'9': nan}     9      NaN
# 3    ABCD1    {'1': 'ABCD1'}     1    ABCD1
# 3    ABCD1     {'2': 'ABCD'}     2     ABCD
# 3    ABCD1      {'3': 'ABC'}     3      ABC
# 3    ABCD1       {'4': 'AB'}     4       AB
# 3    ABCD1        {'5': 'A'}     5        A
# 3    ABCD1        {'6': 'Z'}     6        Z
# 3    ABCD1        {'7': nan}     7      NaN
# 3    ABCD1        {'8': nan}     8      NaN
# 3    ABCD1        {'9': nan}     9      NaN
# 4     ABCD     {'1': 'ABCD'}     1     ABCD
# 4     ABCD      {'2': 'ABC'}     2      ABC
# 4     ABCD       {'3': 'AB'}     3       AB
# 4     ABCD        {'4': 'A'}     4        A
# 4     ABCD        {'5': 'Z'}     5        Z
# 4     ABCD        {'6': nan}     6      NaN
# 4     ABCD        {'7': nan}     7      NaN
# 4     ABCD        {'8': nan}     8      NaN
# 4     ABCD        {'9': nan}     9      NaN
# 5      ABC      {'1': 'ABC'}     1      ABC
# 5      ABC       {'2': 'AB'}     2       AB
# 5      ABC        {'3': 'A'}     3        A
# 5      ABC        {'4': 'Z'}     4        Z
# 5      ABC        {'5': nan}     5      NaN
# 5      ABC        {'6': nan}     6      NaN
# 5      ABC        {'7': nan}     7      NaN
# 5      ABC        {'8': nan}     8      NaN
# 5      ABC        {'9': nan}     9      NaN
# 6       AB       {'1': 'AB'}     1       AB
# 6       AB        {'2': 'A'}     2        A
# 6       AB        {'3': 'Z'}     3        Z
# 6       AB        {'4': nan}     4      NaN
# 6       AB        {'5': nan}     5      NaN
# 6       AB        {'6': nan}     6      NaN
# 6       AB        {'7': nan}     7      NaN
# 6       AB        {'8': nan}     8      NaN
# 6       AB        {'9': nan}     9      NaN
# 7        A        {'1': 'A'}     1        A
# 7        A        {'2': 'Z'}     2        Z
# 7        A        {'3': nan}     3      NaN
# 7        A        {'4': nan}     4      NaN
# 7        A        {'5': nan}     5      NaN
# 7        A        {'6': nan}     6      NaN
# 7        A        {'7': nan}     7      NaN
# 7        A        {'8': nan}     8      NaN
# 7        A        {'9': nan}     9      NaN

# %%
org_new.reset_index(inplace=True)

# %%
#df = df.drop(df[df.score < 50].index)
org_new = org_new.drop(org_new[org_new['parent'].isnull()].index)
org_new.drop(columns = ['kvs'], inplace=True)
#org_new[org_new['parent'].isnull()].index

# %%
org_new.shape
# Out:
# (72, 4)

# %%
org_new
# Out:
#     index        1 depth   parent
# 0       0        x     1        x
# 1       0        x     2  ABCD123
# 2       0        x     3   ABCD12
# 3       0        x     4    ABCD1
# 4       0        x     5     ABCD
# 5       0        x     6      ABC
# 6       0        x     7       AB
# 7       0        x     8        A
# 8       0        x     9        Z
# 9       1  ABCD123     1  ABCD123
# 10      1  ABCD123     2   ABCD12
# 11      1  ABCD123     3    ABCD1
# 12      1  ABCD123     4     ABCD
# 13      1  ABCD123     5      ABC
# 14      1  ABCD123     6       AB
# 15      1  ABCD123     7        A
# 16      1  ABCD123     8        Z
# 18      2   ABCD12     1   ABCD12
# 19      2   ABCD12     2    ABCD1
# 20      2   ABCD12     3     ABCD
# 21      2   ABCD12     4      ABC
# 22      2   ABCD12     5       AB
# 23      2   ABCD12     6        A
# 24      2   ABCD12     7        Z
# 27      3    ABCD1     1    ABCD1
# 28      3    ABCD1     2     ABCD
# 29      3    ABCD1     3      ABC
# 30      3    ABCD1     4       AB
# 31      3    ABCD1     5        A
# 32      3    ABCD1     6        Z
# 36      4     ABCD     1     ABCD
# 37      4     ABCD     2      ABC
# 38      4     ABCD     3       AB
# 39      4     ABCD     4        A
# 40      4     ABCD     5        Z
# 45      5      ABC     1      ABC
# 46      5      ABC     2       AB
# 47      5      ABC     3        A
# 48      5      ABC     4        Z
# 54      6       AB     1       AB
# 55      6       AB     2        A
# 56      6       AB     3        Z
# 63      7        A     1        A
# 64      7        A     2        Z

# %%
org_bk2 = org_bk.copy()

# %%
# Out:
#          1               kvs
# 0        x        {'1': 'x'}
# 0        x  {'2': 'ABCD123'}
# 0        x   {'3': 'ABCD12'}
# 0        x    {'4': 'ABCD1'}
# 0        x     {'5': 'ABCD'}
# 0        x      {'6': 'ABC'}
# 0        x       {'7': 'AB'}
# 0        x        {'8': 'A'}
# 0        x        {'9': 'Z'}
# 1  ABCD123  {'1': 'ABCD123'}
# 1  ABCD123   {'2': 'ABCD12'}
# 1  ABCD123    {'3': 'ABCD1'}
# 1  ABCD123     {'4': 'ABCD'}
# 1  ABCD123      {'5': 'ABC'}
# 1  ABCD123       {'6': 'AB'}
# 1  ABCD123        {'7': 'A'}
# 1  ABCD123        {'8': 'Z'}
# 1  ABCD123        {'9': nan}
# 2   ABCD12   {'1': 'ABCD12'}
# 2   ABCD12    {'2': 'ABCD1'}
# 2   ABCD12     {'3': 'ABCD'}
# 2   ABCD12      {'4': 'ABC'}
# 2   ABCD12       {'5': 'AB'}
# 2   ABCD12        {'6': 'A'}
# 2   ABCD12        {'7': 'Z'}
# 2   ABCD12        {'8': nan}
# 2   ABCD12        {'9': nan}
# 3    ABCD1    {'1': 'ABCD1'}
# 3    ABCD1     {'2': 'ABCD'}
# 3    ABCD1      {'3': 'ABC'}
# 3    ABCD1       {'4': 'AB'}
# 3    ABCD1        {'5': 'A'}
# 3    ABCD1        {'6': 'Z'}
# 3    ABCD1        {'7': nan}
# 3    ABCD1        {'8': nan}
# 3    ABCD1        {'9': nan}
# 4     ABCD     {'1': 'ABCD'}
# 4     ABCD      {'2': 'ABC'}
# 4     ABCD       {'3': 'AB'}
# 4     ABCD        {'4': 'A'}
# 4     ABCD        {'5': 'Z'}
# 4     ABCD        {'6': nan}
# 4     ABCD        {'7': nan}
# 4     ABCD        {'8': nan}
# 4     ABCD        {'9': nan}
# 5      ABC      {'1': 'ABC'}
# 5      ABC       {'2': 'AB'}
# 5      ABC        {'3': 'A'}
# 5      ABC        {'4': 'Z'}
# 5      ABC        {'5': nan}
# 5      ABC        {'6': nan}
# 5      ABC        {'7': nan}
# 5      ABC        {'8': nan}
# 5      ABC        {'9': nan}
# 6       AB       {'1': 'AB'}
# 6       AB        {'2': 'A'}
# 6       AB        {'3': 'Z'}
# 6       AB        {'4': nan}
# 6       AB        {'5': nan}
# 6       AB        {'6': nan}
# 6       AB        {'7': nan}
# 6       AB        {'8': nan}
# 6       AB        {'9': nan}
# 7        A        {'1': 'A'}
# 7        A        {'2': 'Z'}
# 7        A        {'3': nan}
# 7        A        {'4': nan}
# 7        A        {'5': nan}
# 7        A        {'6': nan}
# 7        A        {'7': nan}
# 7        A        {'8': nan}
# 7        A        {'9': nan}
